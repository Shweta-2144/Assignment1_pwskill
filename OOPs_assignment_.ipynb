# %% [markdown]
# # **Python OOPs Questions**

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?

# %% [markdown]
# Object-Oriented Programming (OOP) is a programming style that uses classes and objects to organize code based on real world entities. like name, age, color etc

# %% [markdown]
# 2. What is a class in OOP?

# %% [markdown]
# A class is a blueprint for creating objects.

# %% [markdown]
# 3. What is an object in OOP?

# %% [markdown]
# Object is the instances of class.

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?

# %% [markdown]
# Abstraction is hiding complexity, encapsulation is hiding data inside objects.

# %% [markdown]
# 5. What are dunder methods in Python?

# %% [markdown]
# Dunder methods are special methods in Python that allow customization of object behavior for built-in functions and operators. and it is shown by using double undescore like that (__init__)...

# %% [markdown]
# 6. Explain the concept of inheritance in OOPs.

# %% [markdown]
# Inheritance means one class can use the features (like variables and methods) of another class.

# %% [markdown]
# 7. What is polymorphism in OOP?

# %% [markdown]
# Polymorphism in OOP means the ability of different classes to respond to the same method in different ways.

# %% [markdown]
# 8. How is encapsulation achieved in Python?

# %% [markdown]
# Encapsulation in Python is achieved by using access modifiers:
#
# Public members: Accessible from anywhere (name)
#
# Protected members: Prefix with one underscore (_name) – accessible within class and subclasses
#
# Private members: Prefix with two underscores (__name) – accessible only within the class

# %% [markdown]
# 9. What is a constructor in Python?

# %% [markdown]
# A constructor in Python is a special method called __init__() that is automatically called when an object is created, for example

# %%
class Person:
    def __init__(self, name): #here init is constructor
        self.name = name

# %% [markdown]
# 10. What are class and static methods in Python?

# %% [markdown]
# Class methods in Python use @classmethod and work with the class itself (using cls) and other side static methods use @staticmethod and act like regular functions that don’t access class or instance data.

# %% [markdown]
# 11.What is method overloading in Python?

# %% [markdown]
# Python does not support traditional method overloading , you can define one method per name, but you can use default or variable arguments to simulate it.

# %% [markdown]
# 12.. What is method overriding in OOP?

# %% [markdown]
# It means redefining a method in a child class that already exists in the parent class.

# %% [markdown]
# 13. What is a property decorator in Python?

# %% [markdown]
# By using @property you can access a method like an attribute without calling it with ().

# %% [markdown]
# 14. Why is polymorphism important in OOP?

# %% [markdown]
# It will helps you use the same interface for different types, making code more flexible and reusable.

# %% [markdown]
# 15. What is an abstract class in Python?

# %% [markdown]
# An abstract method is a method declared in an abstract class that does not have an implementation.

# %% [markdown]
# 16. What are the advantages of OOP?

# %% [markdown]
# Reusability, modularity, scalability, and organized code using classes and objects.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?

# %% [markdown]
# Class variable: Shared across all instances.
#
# Instance variable: Unique to each object.

# %% [markdown]
# 18. What is multiple inheritance in Python?

# %% [markdown]
# A class can inherit from more than one parent class.

# %% [markdown]
# 19. Explain the Purpose of __str__ and __repr__ methods in Python?

# %% [markdown]
# __str__ is used for informal string representations, such as printing objects for user.
#
#  __repr__ is used for formal string representations, including debugging, logging, and object inspection.

# %% [markdown]
# 20. what is the Significance of super() in Python?

# %% [markdown]
# It will helps you to call methods from a parent class, useful in inheritance.

# %% [markdown]
# 21. what is the Significance of the __del__ method in Python?

# %% [markdown]
# It's called when an object is deleted.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in python?

# %% [markdown]
# @staticmethod: Doesn’t access class or instance.
#
# @classmethod: Takes cls and can access/modify class state.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?

# %% [markdown]
# Inheritance help us to inherit attributes and methods from another class

# %% [markdown]
# 24. What is method chaining in Python OOP?

# %% [markdown]
# Calling multiple methods on the same object in one line by returning self from each method.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?

# %% [markdown]
# It allows an instance of a class to be called like a function.

# %% [markdown]
# # **Practical Questions**

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %%
a = Animal()
a.speak()
# Out:
# Generic animal sound

# %%
b = Dog()
b.speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
class area:
    def area(self):
        pass

class Circle(area):
    def area(self, radius):
        return 3.14 * radius * radius

class Rectangle(area):
    def area(self, length, width):
        return length * width

# %%
a = Circle()
a.area
# Out:
# <bound method Circle.area of <__main__.Circle object at 0x79fbdfe37e90>>

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self):
        self.type = "Vehicle"

class Car(Vehicle):
    def __init__(self):
        super().__init__()
        self.name = "Car"

class ElectricCar(Car):
    def __init__(self):
        super().__init__()
        self.battery = "100 kWh"

# %%
e_car = ElectricCar()

# %%
print("Type:", e_car.type)
print("Name:", e_car.name)
print("Battery:", e_car.battery)
# Out:
# Type: Vehicle
# Name: Car
# Battery: 100 kWh

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class bird:
    def fly(self):
        pass

class sparrow(bird):
    def fly(self):
        print("sparrow can fly")

class penguin(bird):
    def fly(self):
        print("penguin can't fly")

# %%
a = sparrow()
a.fly()
# Out:
# sparrow can fly

# %%
b = penguin()
b.fly()
# Out:
# penguin can't fly

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")
    def check_balance(self):
        return self.__balance

# %%
acc = BankAccount(1000)
acc.check_balance()
# Out:
# 1000

# %%
acc.deposit(1000)

# %%
acc.check_balance()
# Out:
# 2000

# %%
acc.withdraw(500)

# %%
acc.check_balance()
# Out:
# 1500

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class instrument:
    def play(self):
        pass

class guitar(instrument):
    def play(self):
        print("guitar is playing")

class piano(instrument):
    def play(self):
        print("piano is playing")

# %%
a = instrument()
a.play()

# %%
b = guitar()
b.play()
# Out:
# guitar is playing

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
a = MathOperations()
a.add_numbers(10, 20)
# Out:
# 30

# %%
a = MathOperations()
a.subtract_numbers(10, 20)
# Out:
# -10

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

# %%
a = Person()
a.get_count()
# Out:
# 1

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
a = fraction(10, 20)
print(a)
# Out:
# 10/20

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors..

# %%
class vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return vector(self.x + other.x, self.y + other.y)
    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# %%
a = vector(10, 20)
b = vector(30, 40)
c = a+b

# %%
print(c)
# Out:
# Vector(40, 60)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person():
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def myfunc(self):
        print("Hello sir my name is " + self.name + " and my age is " + str(self.age))

# %%
a = Person("Shweta", 23)
a.myfunc()
# Out:
# Hello sir my name is Shweta and my age is 23

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %%
a = Student("Shweta", [10, 20, 30, 40])
a.average_grade()
# Out:
# 25.0

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
r = Rectangle()
r.set_dimensions(5, 3)

# %%
print(r.area())
# Out:
# 15

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return (hours * rate) + bonus

# %%
e = Employee()
print("Employee Salary:", e.calculate_salary(40, 200))
# Out:
# Employee Salary: 8000

# %%
m = Manager()
print("Manager Salary:", m.calculate_salary(40, 200, 5000))
# Out:
# Manager Salary: 13000

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
a = product("pen", 10, 20)
a.total_price()
# Out:
# 200

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
class Animal:
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo!")

class Sheep(Animal):
    def sound(self):
        print("Baaa!")

# %%
Animal1 = Cow()
Animal1.sound()
# Out:
# Moo!

# %%
Animal2 = Sheep()
Animal2.sound()
# Out:
# Baaa!

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details

# %%
class Book():
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Pages: {self.pages}"

# %%
b = Book("BookName", "Author", 100)

# %%
b.get_book_info()
# Out:
# 'Title: BookName, Author: Author, Pages: 100'

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms

# %%
class house():
    def __init__(self, address, price):
        self.address = address
        self.price = price

class mansion(house):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)

# %%
h = mansion("address", 10000, 10)

# %%
h.address
# Out:
# 'address'

# %%
h.price
# Out:
# 10000
